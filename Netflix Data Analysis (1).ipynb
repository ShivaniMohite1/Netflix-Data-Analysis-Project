# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

plt.style.use('default')

# %%
data = pd.read_csv('netflix1.csv')

# %%
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
data.shape
# Out:
# (8790, 10)

# %%
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
data.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
#Check for NULL Values
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
#Check unique Value
data.nunique()
# Out:
# show_id         8790
# type               2
# title           8787
# director        4528
# country           86
# date_added      1713
# release_year      74
# rating            14
# duration         220
# listed_in        513
# dtype: int64

# %%
#Check for Duplicate values
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicated Value Present.

# %%
#Copy of the dataset
df = data.copy()

# %%
df.shape
# Out:
# (8790, 10)

# %%
#Drop NULL values
df = df.dropna()
df.shape
# Out:
# (8790, 10)

# %%
#Check if there is any duplicate values :
df.duplicated().value_counts()
# Out:
# False    8790
# Name: count, dtype: int64

# %%
#Show_id column :

df.drop(columns="show_id", inplace=True)

# %%
df.head()
# Out:
#       type                             title         director        country  \
# 0    Movie              Dick Johnson Is Dead  Kirsten Johnson  United States
# 1  TV Show                         Ganglands  Julien Leclercq         France
# 2  TV Show                     Midnight Mass    Mike Flanagan  United States
# 3    Movie  Confessions of an Invisible Girl    Bruno Garotti         Brazil
# 4    Movie                           Sankofa     Haile Gerima  United States
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
# 3  9/22/2021          2021  TV-PG    91 min
# 4  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# ...

# %%
# 'Type' column :

df["type"].value_counts()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
# %matplotlib inline
plt.figure(figsize = (8, 6))

colors = ['#778fe6','#cfd4e8']

df["type"].value_counts().plot(kind = "pie", autopct="%0.1f%%",explode=[0,0.1], shadow=True, 
                               ylabel='Count', colors=colors, legend=type)
plt.title('Types of show', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Types of show')

# %%
# 'director' column :

df.director.nunique()
# Out:
# 4528

# %%
df['director'].value_counts()
# Out:
# director
# Not Given                         2588
# Rajiv Chilaka                       20
# Alastair Fothergill                 18
# Raúl Campos, Jan Suter              18
# Suhas Kadav                         16
#                                   ...
# Matt D'Avella                        1
# Parthiban                            1
# Scott McAboy                         1
# Raymie Muzquiz, Stu Livingston       1
# Mozez Singh                          1
# Name: count, Length: 4528, dtype: int64

# %%
#Movies and Tv Shows from the 'Not Given' directors :

df[df.director == "Not Given"]
# Out:
#          type                            title   director        country  \
# 12      Movie                 99 Songs (Tamil)  Not Given       Pakistan
# 17    TV Show            Jailbirds New Orleans  Not Given       Pakistan
# 18    TV Show  Crime Stories: India Detectives  Not Given       Pakistan
# 33    TV Show                           Jaguar  Not Given       Pakistan
# 34    TV Show               Chicago Party Aunt  Not Given       Pakistan
# ...       ...                              ...        ...            ...
# 8785  TV Show                       Yunus Emre  Not Given         Turkey
# 8786  TV Show                        Zak Storm  Not Given  United States
# 8787  TV Show               Zindagi Gulzar Hai  Not Given       Pakistan
# 8788  TV Show                             Yoko  Not Given       Pakistan
# 8789  TV Show                              YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# ...

# %%
# %matplotlib inline
plt.figure(figsize = (8, 6))

top_10 = df['director'].value_counts().drop('Not Given').head(10)

sns.barplot(x=top_10.values, y=top_10.index, color='#778fe6')
plt.title("\nTop 10 Directors\n", fontsize = 14, fontweight = 'heavy')
plt.show()

# %%
# 'Country' column :

df['country'].value_counts()
# Out:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
#                   ...
# Iran                 1
# West Germany         1
# Greece               1
# Zimbabwe             1
# Soviet Union         1
# Name: count, Length: 86, dtype: int64

# %%
df[df.country == "Not Given"]
# Out:
#          type                                              title  \
# 23      Movie                   My Little Pony: A New Generation
# 24    TV Show                                   Bangkok Breaking
# 25      Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 26      Movie                                    Samudri Lootere
# 52      Movie                                          Intrusion
# ...       ...                                                ...
# 6005    Movie            Teenage Mutant Ninja Turtles: The Movie
# 6257    Movie                                    The Perfect Day
# 6366    Movie                      Tom and Jerry: The Magic Ring
# 6468    Movie                             Westside vs. the World
# 6499    Movie                             World's Weirdest Homes
#
#                                            director    country  date_added  \
# 23                    Robert Cullen, José Luis Ucha  Not Given   9/24/2021
# ...

# %%
# %matplotlib inline
plt.figure(figsize = (8, 6))

top_10 = df['country'].value_counts().drop('Not Given').head(10)

sns.barplot(x=top_10.values, y=top_10.index, color='#778fe6')
plt.title("\nTop 10 Countries\n", fontsize = 14, fontweight = 'heavy')
plt.show()

# %%
df['date_added'] = pd.to_datetime(df['date_added'])
df.sample(5)
# Out:
#          type                                      title  \
# 4917    Movie  Forbidden Games: The Justin Fashanu Story
# 3512  TV Show                            The Night Shift
# 8370  TV Show                        Big Bad Beetleborgs
# 6943  TV Show                        Marvel Anime: X-Men
# 5312    Movie                  Legend of the Naga Pearls
#
#                    director         country date_added  release_year rating  \
# 4917  Jon Carey, Adam Darke  United Kingdom 2017-12-01          2017  TV-14
# 3512              Not Given   United States 2018-06-07          2017  TV-14
# 8370              Not Given   United States 2016-01-01          1997   TV-G
# 6943              Not Given           Japan 2020-12-16          2011  TV-14
# 5312               Yang Lei           China 2018-03-30          2017  TV-MA
#
#        duration                                          listed_in
# 4917     81 min  Documentaries, International Movies, LGBTQ Movies
# ...

# %%
print(df['date_added'].min())
print(df['date_added'].max())
# Out:
# 2008-01-01 00:00:00
# 2021-09-25 00:00:00

# %%
# 'release_year' column :

released_year = df.release_year.value_counts()   
released_year
# Out:
# release_year
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
#         ...
# 1966       1
# 1959       1
# 1925       1
# 1947       1
# 1961       1
# Name: count, Length: 74, dtype: int64

# %%
# %matplotlib inline
plt.figure(figsize = (8,6))
sns.lineplot(x = released_year.head(15).index , y = released_year.head(15).values, marker='o');

# %%
# 'Rating' Column :

rating  = df.rating.value_counts()
rating
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
# %matplotlib inline
plt.figure(figsize=(8,6))
x=rating.plot(kind="bar",color=sns.color_palette("ch:s=.25,rot=-.25"),edgecolor="black")
for i in x.patches:
    x.annotate(int(i.get_height()),(i.get_x()+0.25,i.get_height()+1),ha="center",va="bottom")
    x.tick_params(axis="both",labelsize=10)
plt.title("rating\n",fontsize=15)
# Out:
# Text(0.5, 1.0, 'rating\n')

# %%
# 'Duration' Column :

df["duration"].value_counts()
# Out:
# duration
# 1 Season      1791
# 2 Seasons      421
# 3 Seasons      198
# 90 min         152
# 97 min         146
#               ...
# 5 min            1
# 16 min           1
# 186 min          1
# 193 min          1
# 11 Seasons       1
# Name: count, Length: 220, dtype: int64

# %%
df.rename(columns={"listed_in":"category"}, inplace=True)
df.columns
# Out:
# Index(['type', 'title', 'director', 'country', 'date_added', 'release_year',
#        'rating', 'duration', 'category'],
#       dtype='object')

# %%
category = df.category.value_counts()
category
# Out:
# category
# Dramas, International Movies                                362
# Documentaries                                               359
# Stand-Up Comedy                                             334
# Comedies, Dramas, International Movies                      274
# Dramas, Independent Movies, International Movies            252
#                                                            ...
# Anime Features                                                1
# Action & Adventure, Horror Movies, Independent Movies         1
# Action & Adventure, Classic Movies, International Movies      1
# Cult Movies, Independent Movies, Thrillers                    1
# Classic & Cult TV, Crime TV Shows, TV Dramas                  1
# Name: count, Length: 513, dtype: int64

# %%
# %matplotlib inline
plt.figure(figsize=(8,6))
x=category.head(15).plot(kind="bar",color=sns.color_palette("ch:s=.25,rot=-.25"),edgecolor="black")
for i in x.patches:
    x.annotate(int(i.get_height()),(i.get_x()+0.25,i.get_height()+1),ha="center",va="bottom")
    x.tick_params(axis="both",labelsize=10)
plt.title("categories\n",fontsize=15)
# Out:
# Text(0.5, 1.0, 'categories\n')

# %%
# What are top 3 Countries which netflix has the most show[ movies & tv shows ] from

# %matplotlib inline
plt.figure(figsize=(8,6))

colors = ['#778fe6','#cfd4e8','#9296a6']
top_3 = df['country'].value_counts().drop('Not Given').head(3)

top_3.plot(kind = "pie", autopct="%0.1f%%",explode=[0,0,0], shadow=True, 
                               ylabel='Count', colors=colors, legend=type)
plt.title('\nTop 3 country\n', fontsize=15)
# Out:
# Text(0.5, 1.0, '\nTop 3 country\n')

# %%
# What are top 3 Countries which netflix has the most "TV show" from?

top_3_Tv = df.country[df.type=="TV Show"].value_counts()[:3]
top_3_Tv
# Out:
# country
# United States     845
# Pakistan          350
# United Kingdom    251
# Name: count, dtype: int64

# %%
# %matplotlib inline
plt.figure(figsize=(8,6))
x=top_3_Tv.plot(kind="bar")
for i in x.patches:
    x.annotate(int(i.get_height()),(i.get_x()+0.25,i.get_height()+1),ha="center",va="bottom");
plt.title('Top 3 Countries which netflix has the most TV shows from\n\n',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Top 3 Countries which netflix has the most TV shows from\n\n')

# %%
#What are top 3 Countries which netflix has the most "Movies" from?

top_3_Movie = df.country[df.type=="Movie"].value_counts()[:3]
top_3_Movie
# Out:
# country
# United States     2395
# India              976
# United Kingdom     387
# Name: count, dtype: int64

# %%
# %matplotlib inline
plt.figure(figsize=(8,6))
x=top_3_Movie.plot(kind="bar")
for i in x.patches:
    x.annotate(int(i.get_height()),(i.get_x()+0.25,i.get_height()+1),ha="center",va="bottom");
plt.title('Top 3 Countries which netflix has the most Movies from\n\n',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Top 3 Countries which netflix has the most Movies from\n\n')

# %%
# What is number of Movies and TV Shows added per month?

df["month-date_added"]=df["date_added"].dt.month_name()
df["month-date_added"].value_counts()
# Out:
# month-date_added
# July         827
# December     812
# September    769
# April        763
# October      760
# August       754
# March        741
# January      737
# June         728
# November     705
# May          632
# February     562
# Name: count, dtype: int64

# %%
# %matplotlib inline
plt.figure(figsize=(8,6))
x=df["month-date_added"].value_counts().plot(kind="bar",color=sns.color_palette("ch:s=.25,rot=-.25"),edgecolor="black")
for i in x.patches:
    x.annotate(int(i.get_height()),(i.get_x()+0.25,i.get_height()+1),ha="center",va="bottom")
    x.tick_params(axis="both",labelsize=10)
plt.title("show added per month\n",fontsize=15)
# Out:
# Text(0.5, 1.0, 'show added per month\n')

# %%
# What is number of Movies and TV Shows added per year?

df["year-date_added"]=df["date_added"].dt.year
df["year-date_added"].value_counts()
# Out:
# year-date_added
# 2019    2016
# 2020    1879
# 2018    1648
# 2021    1498
# 2017    1185
# 2016     426
# 2015      82
# 2014      24
# 2011      13
# 2013      11
# 2012       3
# 2009       2
# 2008       2
# 2010       1
# Name: count, dtype: int64

# %%
# %matplotlib inline
plt.figure(figsize=(8,6))
x=df["year-date_added"].value_counts().plot(kind="bar",color=sns.color_palette("ch:s=.25,rot=-.25"),edgecolor="black")
for i in x.patches:
    x.annotate(int(i.get_height()),(i.get_x()+0.25,i.get_height()+1),ha="center",va="bottom")
    x.tick_params(axis="both",labelsize=10)
plt.title("shows added per year\n",fontsize=15)
# Out:
# Text(0.5, 1.0, 'shows added per year\n')

# %%
#Who are the top 5 directors with the most Movies and TV Shows?

directors = df.director.value_counts().drop('Not Given')[:5]
directors
# Out:
# director
# Rajiv Chilaka             20
# Alastair Fothergill       18
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Name: count, dtype: int64

# %%
# %matplotlib inline
plt.figure(figsize=(8,6))
x=directors.plot(kind="bar")
for i in x.patches:
    x.annotate(int(i.get_height()),(i.get_x()+0.25,i.get_height()+1),ha="center",va="bottom");
plt.title('Top 5 Directors\n\n',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Top 5 Directors\n\n')

# %%
# what is the most common rating for each type of show?

rating_tv = df.rating[df.type=="TV Show"].value_counts()
rating_tv
# Out:
# rating
# TV-MA       1143
# TV-14        730
# TV-PG        321
# TV-Y7        194
# TV-Y         175
# TV-G          94
# NR             4
# R              2
# TV-Y7-FV       1
# Name: count, dtype: int64

# %%
rating_movie = df.rating[df.type=="Movie"].value_counts()
rating_movie
# Out:
# rating
# TV-MA       2062
# TV-14       1427
# R            797
# TV-PG        540
# PG-13        490
# PG           287
# TV-Y7        139
# TV-Y         131
# TV-G         126
# NR            75
# G             41
# TV-Y7-FV       5
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 6))

rating_movie.plot(kind='bar', ax=axes[0])
axes[0].set_title('Movie Ratings')
axes[0].set_xlabel('rating')
axes[0].set_ylabel('Count')

rating_tv.plot(kind='bar', ax=axes[1])
axes[1].set_title('TV Show Ratings')
axes[1].set_xlabel('rating')
axes[1].set_ylabel('Count')

plt.tight_layout()
plt.show()
